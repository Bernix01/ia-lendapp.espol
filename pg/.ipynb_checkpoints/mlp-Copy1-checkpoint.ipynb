# %%
# !pip install pandas pydot-ng
# Out:
# Requirement already satisfied: pandas in c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages (1.1.1)
# Requirement already satisfied: pydot-ng in c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages (2.0.0)
# Requirement already satisfied: pytz>=2017.2 in c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages (from pandas) (1.19.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pyparsing>=2.0.1 in c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages (from pydot-ng) (2.4.7)
# Requirement already satisfied: six>=1.5 in c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# WARNING: You are using pip version 19.2.3, however version 20.2.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
# %load_ext tensorboard
import tensorflow as tf
import numpy as np
import pandas as pd
from tensorflow import keras
from tensorflow.keras import layers
import datetime

# %%
file_url = "input_data.csv"
dataframe = pd.read_csv(file_url, dtype= {
'loan_amnt': np.float32,
'index': int,
'term' : str, 
'installment' : np.float32,
'emp_title' : 'str', 
'purpose' : 'str', 
'title' : 'str', 
'dti' : np.float32,
'collections_12_mths_ex_med' : np.float32,
'application_type' : 'str', 
'tot_coll_amt' : np.float32,
'tot_cur_bal' : np.float32,
'open_acc_6m' : np.float32,
'open_act_il' : np.float32,
'open_il_12m' : np.float32,
'open_il_24m' : np.float32,
'mths_since_rcnt_il' : np.float32,
'total_bal_il' : np.float32,
'open_rv_12m' : np.float32,
'open_rv_24m' : np.float32,
'max_bal_bc' : np.float32,
'all_util' : np.float32,
'inq_fi' : np.float32,
'total_cu_tl' : np.float32,
'inq_last_12m' : np.float32,
'avg_cur_bal' : np.float32,
'chargeoff_within_12_mths' : np.float32,
'mo_sin_old_rev_tl_op' : np.float32,
'mo_sin_rcnt_rev_tl_op' : np.float32,
'mo_sin_rcnt_tl' : np.float32,
'num_accts_ever_120_pd' : np.float32,
'num_actv_bc_tl' : np.float32,
'num_actv_rev_tl' : np.float32,
'num_bc_sats' : np.float32,
'num_bc_tl' : np.float32,
'num_il_tl' : np.float32,
'num_op_rev_tl' : np.float32,
'num_rev_accts' : np.float32,
'num_rev_tl_bal_gt_0' : np.float32,
'num_sats' : np.float32,
'num_tl_120dpd_2m' : np.float32,
'num_tl_30dpd' : np.float32,
'num_tl_90g_dpd_24m' : np.float32,
'num_tl_op_past_12m' : np.float32,
'pct_tl_nvr_dlq' : np.float32,
'pub_rec_bankruptcies' : np.float32,
'tax_liens' : np.float32,
'tot_hi_cred_lim' : np.float32,
'total_il_high_credit_limit' : np.float32,
'disbursement_method' : 'str', 
'is_risky' : np.int32,
    })
dataframe.set_index("index", inplace=True)
dataframe.dropna(inplace=True)
dataframe.reset_index(drop=True,inplace=True)

# %%
to_int_cols = ['chargeoff_within_12_mths', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'pub_rec_bankruptcies']
dataframe[to_int_cols] = dataframe[to_int_cols].astype(np.int32)

# %%
dataframe.shape
# Out:
# (1172538, 50)

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1172538 entries, 0 to 1172537
# Data columns (total 50 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   loan_amnt                   1172538 non-null  float32
#  1   term                        1172538 non-null  object
#  2   installment                 1172538 non-null  float32
#  3   emp_title                   1172538 non-null  object
#  4   purpose                     1172538 non-null  object
#  5   title                       1172538 non-null  object
#  6   dti                         1172538 non-null  float32
#  7   collections_12_mths_ex_med  1172538 non-null  float32
#  8   application_type            1172538 non-null  object
#  9   tot_coll_amt                1172538 non-null  float32
#  10  tot_cur_bal                 1172538 non-null  float32
#  11  open_acc_6m                 1172538 non-null  float32
#  12  open_act_il                 1172538 non-null  float32
#  13  open_il_12m                 1172538 non-null  float32
#  14  open_il_24m                 1172538 non-null  float32
#  15  mths_since_rcnt_il          1172538 non-null  float32
#  16  total_bal_il                1172538 non-null  float32
#  17  open_rv_12m                 1172538 non-null  float32
#  18  open_rv_24m                 1172538 non-null  float32
#  19  max_bal_bc                  1172538 non-null  float32
#  20  all_util                    1172538 non-null  float32
#  21  inq_fi                      1172538 non-null  float32
#  22  total_cu_tl                 1172538 non-null  float32
#  23  inq_last_12m                1172538 non-null  float32
#  24  avg_cur_bal                 1172538 non-null  float32
#  25  chargeoff_within_12_mths    1172538 non-null  int32
#  26  mo_sin_old_rev_tl_op        1172538 non-null  float32
#  27  mo_sin_rcnt_rev_tl_op       1172538 non-null  float32
#  28  mo_sin_rcnt_tl              1172538 non-null  float32
#  29  num_accts_ever_120_pd       1172538 non-null  float32
#  30  num_actv_bc_tl              1172538 non-null  float32
#  31  num_actv_rev_tl             1172538 non-null  float32
#  32  num_bc_sats                 1172538 non-null  float32
#  33  num_bc_tl                   1172538 non-null  float32
#  34  num_il_tl                   1172538 non-null  float32
#  35  num_op_rev_tl               1172538 non-null  float32
#  36  num_rev_accts               1172538 non-null  float32
#  37  num_rev_tl_bal_gt_0         1172538 non-null  float32
#  38  num_sats                    1172538 non-null  float32
#  39  num_tl_120dpd_2m            1172538 non-null  int32
#  40  num_tl_30dpd                1172538 non-null  int32
#  41  num_tl_90g_dpd_24m          1172538 non-null  float32
#  42  num_tl_op_past_12m          1172538 non-null  float32
#  43  pct_tl_nvr_dlq              1172538 non-null  float32
#  44  pub_rec_bankruptcies        1172538 non-null  int32
#  45  tax_liens                   1172538 non-null  float32
#  46  tot_hi_cred_lim             1172538 non-null  float32
#  47  total_il_high_credit_limit  1172538 non-null  float32
#  48  disbursement_method         1172538 non-null  object
#  49  is_risky                    1172538 non-null  int32
# dtypes: float32(39), int32(5), object(6)
# memory usage: 250.5+ MB

# %%
val_dataframe = dataframe.sample(frac=0.6, random_state=1337)
train_dataframe = dataframe.drop(val_dataframe.index)

print(
    "Using %d samples for training and %d for validation"
    % (len(train_dataframe), len(val_dataframe))
)
# Out:
# Using 469015 samples for training and 703523 for validation

# %%
def dataframe_to_dataset(dataframe):
    dataframe = dataframe.copy()
    labels = dataframe.pop("is_risky")
    ds = tf.data.Dataset.from_tensor_slices((dict(dataframe), labels))
    ds = ds.shuffle(buffer_size=len(dataframe))
    return ds


train_ds = dataframe_to_dataset(train_dataframe)
val_ds = dataframe_to_dataset(val_dataframe)

# %%
for x, y in train_ds.take(1):
    print("Input:", x)
    print("Target:", y)
# Out:
# Input: {'loan_amnt': <tf.Tensor: shape=(), dtype=float32, numpy=6000.0>, 'term': <tf.Tensor: shape=(), dtype=string, numpy=b' 36 months'>, 'installment': <tf.Tensor: shape=(), dtype=float32, numpy=185.84>, 'emp_title': <tf.Tensor: shape=(), dtype=string, numpy=b'Heavy equipment operater'>, 'purpose': <tf.Tensor: shape=(), dtype=string, numpy=b'credit_card'>, 'title': <tf.Tensor: shape=(), dtype=string, numpy=b'Credit card refinancing'>, 'dti': <tf.Tensor: shape=(), dtype=float32, numpy=9.38>, 'collections_12_mths_ex_med': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'application_type': <tf.Tensor: shape=(), dtype=string, numpy=b'Individual'>, 'tot_coll_amt': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'tot_cur_bal': <tf.Tensor: shape=(), dtype=float32, numpy=26554.0>, 'open_acc_6m': <tf.Tensor: shape=(), dtype=float32, numpy=1.0>, 'open_act_il': <tf.Tensor: shape=(), dtype=float32, numpy=1.0>, 'open_il_12m': <tf.Tensor: shape=(), dtype=float32, numpy=1.0>, 'open_il_24m': <tf.Tensor: shape=(), dtype=float32, numpy=1.0>, 'mths_since_rcnt_il': <tf.Tensor: shape=(), dtype=float32, numpy=4.0>, 'total_bal_il': <tf.Tensor: shape=(), dtype=float32, numpy=23677.0>, 'open_rv_12m': <tf.Tensor: shape=(), dtype=float32, numpy=1.0>, 'open_rv_24m': <tf.Tensor: shape=(), dtype=float32, numpy=1.0>, 'max_bal_bc': <tf.Tensor: shape=(), dtype=float32, numpy=1539.0>, 'all_util': <tf.Tensor: shape=(), dtype=float32, numpy=60.0>, 'inq_fi': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'total_cu_tl': <tf.Tensor: shape=(), dtype=float32, numpy=1.0>, 'inq_last_12m': <tf.Tensor: shape=(), dtype=float32, numpy=1.0>, 'avg_cur_bal': <tf.Tensor: shape=(), dtype=float32, numpy=4426.0>, 'chargeoff_within_12_mths': <tf.Tensor: shape=(), dtype=int32, numpy=0>, 'mo_sin_old_rev_tl_op': <tf.Tensor: shape=(), dtype=float32, numpy=77.0>, 'mo_sin_rcnt_rev_tl_op': <tf.Tensor: shape=(), dtype=float32, numpy=9.0>, 'mo_sin_rcnt_tl': <tf.Tensor: shape=(), dtype=float32, numpy=4.0>, 'num_accts_ever_120_pd': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'num_actv_bc_tl': <tf.Tensor: shape=(), dtype=float32, numpy=2.0>, 'num_actv_rev_tl': <tf.Tensor: shape=(), dtype=float32, numpy=2.0>, 'num_bc_sats': <tf.Tensor: shape=(), dtype=float32, numpy=4.0>, 'num_bc_tl': <tf.Tensor: shape=(), dtype=float32, numpy=4.0>, 'num_il_tl': <tf.Tensor: shape=(), dtype=float32, numpy=3.0>, 'num_op_rev_tl': <tf.Tensor: shape=(), dtype=float32, numpy=5.0>, 'num_rev_accts': <tf.Tensor: shape=(), dtype=float32, numpy=5.0>, 'num_rev_tl_bal_gt_0': <tf.Tensor: shape=(), dtype=float32, numpy=2.0>, 'num_sats': <tf.Tensor: shape=(), dtype=float32, numpy=6.0>, 'num_tl_120dpd_2m': <tf.Tensor: shape=(), dtype=int32, numpy=0>, 'num_tl_30dpd': <tf.Tensor: shape=(), dtype=int32, numpy=0>, 'num_tl_90g_dpd_24m': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'num_tl_op_past_12m': <tf.Tensor: shape=(), dtype=float32, numpy=2.0>, 'pct_tl_nvr_dlq': <tf.Tensor: shape=(), dtype=float32, numpy=100.0>, 'pub_rec_bankruptcies': <tf.Tensor: shape=(), dtype=int32, numpy=0>, 'tax_liens': <tf.Tensor: shape=(), dtype=float32, numpy=0.0>, 'tot_hi_cred_lim': <tf.Tensor: shape=(), dtype=float32, numpy=43952.0>, 'total_il_high_credit_limit': <tf.Tensor: shape=(), dtype=float32, numpy=24552.0>, 'disbursement_method': <tf.Tensor: shape=(), dtype=string, numpy=b'Cash'>}
# Target: tf.Tensor(1, shape=(), dtype=int32)

# %%
train_ds = train_ds.batch(32)
val_ds = val_ds.batch(32)

# %%
from tensorflow.keras.layers.experimental.preprocessing import Normalization
from tensorflow.keras.layers.experimental.preprocessing import CategoryEncoding
from tensorflow.keras.layers.experimental.preprocessing import StringLookup


def encode_numerical_feature(feature, name, dataset):
    # Create a Normalization layer for our feature
    normalizer = Normalization()

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the statistics of the data
    normalizer.adapt(feature_ds)

    # Normalize the input feature
    encoded_feature = normalizer(feature)
    return encoded_feature


def encode_string_categorical_feature(feature, name, dataset):
    # Create a StringLookup layer which will turn strings into integer indices
    index = StringLookup()

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the set of possible string values and assign them a fixed integer index
    index.adapt(feature_ds)

    # Turn the string input into integer indices
    encoded_feature = index(feature)

    # Create a CategoryEncoding for our integer indices
    encoder = CategoryEncoding(output_mode="binary", max_tokens=20)

    # Prepare a dataset of indices
    feature_ds = feature_ds.map(index)

    # Learn the space of possible indices
    encoder.adapt(feature_ds)

    # Apply one-hot encoding to our indices
    encoded_feature = encoder(encoded_feature)
    return encoded_feature


def encode_integer_categorical_feature(feature, name, dataset):
    # Create a CategoryEncoding for our integer indices
    encoder = CategoryEncoding(output_mode="binary", max_tokens=20)

    # Prepare a Dataset that only yields our feature
    feature_ds = dataset.map(lambda x, y: x[name])
    feature_ds = feature_ds.map(lambda x: tf.expand_dims(x, -1))

    # Learn the space of possible indices
    encoder.adapt(feature_ds)

    # Apply one-hot encoding to our indices
    encoded_feature = encoder(feature)
    return encoded_feature

# %%
#Categorical feature encoded as numeric
chargeoff_within_12_mths = keras.Input(shape=(1,),name="chargeoff_within_12_mths",dtype="int64")
num_tl_120dpd_2m = keras.Input(shape=(1,), name="num_tl_120dpd_2m", dtype="int64")
num_tl_30dpd = keras.Input(shape=(1,), name="num_tl_30dpd", dtype="int64")
pub_rec_bankruptcies = keras.Input(shape=(1,), name="pub_rec_bankruptcies", dtype="int64")

# Categorical feature encoded as string
application_type = keras.Input(shape=(1,), name="application_type", dtype="string")
disbursement_method = keras.Input(shape=(1,), name="disbursement_method", dtype="string")
emp_title = keras.Input(shape=(1,), name="emp_title", dtype="string")
purpose = keras.Input(shape=(1,), name="purpose", dtype="string")
term = keras.Input(shape=(1,), name="term", dtype="string")
title = keras.Input(shape=(1,), name="title", dtype="string")

# Numerical features
loan_amnt = keras.Input(shape=(1,),name="loan_amnt")
all_util = keras.Input(shape=(1,),name="all_util")
avg_cur_bal = keras.Input(shape=(1,), name="avg_cur_bal")
collections_12_mths_ex_med = keras.Input(shape=(1,), name="collections_12_mths_ex_med")
dti = keras.Input(shape=(1,), name="dti")
inq_fi = keras.Input(shape=(1,), name="inq_fi")
inq_last_12m = keras.Input(shape=(1,), name="inq_last_12m")
installment = keras.Input(shape=(1,), name="installment")
max_bal_bc = keras.Input(shape=(1,), name="max_bal_bc")
mo_sin_old_rev_tl_op = keras.Input(shape=(1,), name="mo_sin_old_rev_tl_op")
mo_sin_rcnt_rev_tl_op = keras.Input(shape=(1,), name="mo_sin_rcnt_rev_tl_op")
mo_sin_rcnt_tl = keras.Input(shape=(1,), name="mo_sin_rcnt_tl")
mths_since_rcnt_il = keras.Input(shape=(1,), name="mths_since_rcnt_il")
num_accts_ever_120_pd = keras.Input(shape=(1,), name="num_accts_ever_120_pd")
num_actv_bc_tl = keras.Input(shape=(1,), name="num_actv_bc_tl")
num_actv_rev_tl = keras.Input(shape=(1,), name="num_actv_rev_tl")
num_bc_sats = keras.Input(shape=(1,), name="num_bc_sats")
num_bc_tl = keras.Input(shape=(1,), name="num_bc_tl")
num_il_tl = keras.Input(shape=(1,), name="num_il_tl")
num_op_rev_tl = keras.Input(shape=(1,), name="num_op_rev_tl")
num_rev_accts = keras.Input(shape=(1,), name="num_rev_accts")
num_rev_tl_bal_gt_0 = keras.Input(shape=(1,), name="num_rev_tl_bal_gt_0")
num_sats = keras.Input(shape=(1,), name="num_sats")
num_tl_90g_dpd_24m = keras.Input(shape=(1,), name="num_tl_90g_dpd_24m")
num_tl_op_past_12m = keras.Input(shape=(1,), name="num_tl_op_past_12m")
open_acc_6m = keras.Input(shape=(1,), name="open_acc_6m")
open_act_il = keras.Input(shape=(1,), name="open_act_il")
open_il_12m = keras.Input(shape=(1,), name="open_il_12m")
open_il_24m = keras.Input(shape=(1,), name="open_il_24m")
open_rv_12m = keras.Input(shape=(1,), name="open_rv_12m")
open_rv_24m = keras.Input(shape=(1,), name="open_rv_24m")
pct_tl_nvr_dlq = keras.Input(shape=(1,), name="pct_tl_nvr_dlq")
tax_liens = keras.Input(shape=(1,), name="tax_liens")
tot_coll_amt = keras.Input(shape=(1,), name="tot_coll_amt")
tot_cur_bal = keras.Input(shape=(1,), name="tot_cur_bal")
tot_hi_cred_lim = keras.Input(shape=(1,), name="tot_hi_cred_lim")
total_bal_il = keras.Input(shape=(1,), name="total_bal_il")
total_cu_tl = keras.Input(shape=(1,), name="total_cu_tl")
total_il_high_credit_limit = keras.Input(shape=(1,), name="total_il_high_credit_limit")


#Categorical feature encoded as numeric
chargeoff_within_12_mths_encoded = encode_integer_categorical_feature(chargeoff_within_12_mths, "chargeoff_within_12_mths",train_ds)
num_tl_120dpd_2m_encoded = encode_integer_categorical_feature(num_tl_120dpd_2m, "num_tl_120dpd_2m", train_ds)
num_tl_30dpd_encoded = encode_integer_categorical_feature(num_tl_30dpd, "num_tl_30dpd", train_ds)
pub_rec_bankruptcies_encoded = encode_integer_categorical_feature(pub_rec_bankruptcies, "pub_rec_bankruptcies", train_ds)

# Categorical feature encoded as string
application_type_encoded = encode_string_categorical_feature(application_type, "application_type", train_ds)
disbursement_method_encoded = encode_string_categorical_feature(disbursement_method, "disbursement_method", train_ds)
emp_title_encoded = encode_string_categorical_feature(emp_title, "emp_title", train_ds)
purpose_encoded = encode_string_categorical_feature(purpose, "purpose", train_ds)
term_encoded = encode_string_categorical_feature(term, "term", train_ds)
title_encoded = encode_string_categorical_feature(title, "title", train_ds)

# Numerical features
loan_amnt_encoded = encode_numerical_feature(loan_amnt, "loan_amnt", train_ds)
all_util_encoded = encode_numerical_feature(all_util, "all_util", train_ds)
avg_cur_bal_encoded = encode_numerical_feature(avg_cur_bal, "avg_cur_bal", train_ds)
collections_12_mths_ex_med_encoded = encode_numerical_feature(collections_12_mths_ex_med, "collections_12_mths_ex_med", train_ds)
dti_encoded = encode_numerical_feature(dti, "dti", train_ds)
inq_fi_encoded = encode_numerical_feature(inq_fi, "inq_fi", train_ds)
inq_last_12m_encoded = encode_numerical_feature(inq_last_12m, "inq_last_12m", train_ds)
installment_encoded = encode_numerical_feature(installment, "installment", train_ds)
max_bal_bc_encoded = encode_numerical_feature(max_bal_bc, "max_bal_bc", train_ds)
mo_sin_old_rev_tl_op_encoded = encode_numerical_feature(mo_sin_old_rev_tl_op, "mo_sin_old_rev_tl_op", train_ds)
mo_sin_rcnt_rev_tl_op_encoded = encode_numerical_feature(mo_sin_rcnt_rev_tl_op, "mo_sin_rcnt_rev_tl_op", train_ds)
mo_sin_rcnt_tl_encoded = encode_numerical_feature(mo_sin_rcnt_tl, "mo_sin_rcnt_tl", train_ds)
mths_since_rcnt_il_encoded = encode_numerical_feature(mths_since_rcnt_il, "mths_since_rcnt_il", train_ds)
num_accts_ever_120_pd_encoded = encode_numerical_feature(num_accts_ever_120_pd, "num_accts_ever_120_pd", train_ds)
num_actv_bc_tl_encoded = encode_numerical_feature(num_actv_bc_tl, "num_actv_bc_tl", train_ds)
num_actv_rev_tl_encoded = encode_numerical_feature(num_actv_rev_tl, "num_actv_rev_tl", train_ds)
num_bc_sats_encoded = encode_numerical_feature(num_bc_sats, "num_bc_sats", train_ds)
num_bc_tl_encoded = encode_numerical_feature(num_bc_tl, "num_bc_tl", train_ds)
num_il_tl_encoded = encode_numerical_feature(num_il_tl, "num_il_tl", train_ds)
num_op_rev_tl_encoded = encode_numerical_feature(num_op_rev_tl, "num_op_rev_tl", train_ds)
num_rev_accts_encoded = encode_numerical_feature(num_rev_accts, "num_rev_accts", train_ds)
num_rev_tl_bal_gt_0_encoded = encode_numerical_feature(num_rev_tl_bal_gt_0, "num_rev_tl_bal_gt_0", train_ds)
num_sats_encoded = encode_numerical_feature(num_sats, "num_sats", train_ds)
num_tl_90g_dpd_24m_encoded = encode_numerical_feature(num_tl_90g_dpd_24m, "num_tl_90g_dpd_24m", train_ds)
num_tl_op_past_12m_encoded = encode_numerical_feature(num_tl_op_past_12m, "num_tl_op_past_12m", train_ds)
open_acc_6m_encoded = encode_numerical_feature(open_acc_6m, "open_acc_6m", train_ds)
open_act_il_encoded = encode_numerical_feature(open_act_il, "open_act_il", train_ds)
open_il_12m_encoded = encode_numerical_feature(open_il_12m, "open_il_12m", train_ds)
open_il_24m_encoded = encode_numerical_feature(open_il_24m, "open_il_24m", train_ds)
open_rv_12m_encoded = encode_numerical_feature(open_rv_12m, "open_rv_12m", train_ds)
open_rv_24m_encoded = encode_numerical_feature(open_rv_24m, "open_rv_24m", train_ds)
pct_tl_nvr_dlq_encoded = encode_numerical_feature(pct_tl_nvr_dlq, "pct_tl_nvr_dlq", train_ds)
tax_liens_encoded = encode_numerical_feature(tax_liens, "tax_liens", train_ds)
tot_coll_amt_encoded = encode_numerical_feature(tot_coll_amt, "tot_coll_amt", train_ds)
tot_cur_bal_encoded = encode_numerical_feature(tot_cur_bal, "tot_cur_bal", train_ds)
tot_hi_cred_lim_encoded = encode_numerical_feature(tot_hi_cred_lim, "tot_hi_cred_lim", train_ds)
total_bal_il_encoded = encode_numerical_feature(total_bal_il, "total_bal_il", train_ds)
total_cu_tl_encoded = encode_numerical_feature(total_cu_tl, "total_cu_tl", train_ds)
total_il_high_credit_limit_encoded = encode_numerical_feature(total_il_high_credit_limit, "total_il_high_credit_limit", train_ds)

# %%
all_inputs = [
     application_type,
#     chargeoff_within_12_mths,
#     emp_title,
#     inq_fi,
#     inq_last_12m,
#     mo_sin_old_rev_tl_op,
#     mo_sin_rcnt_rev_tl_op,
#     mo_sin_rcnt_tl,
#     mths_since_rcnt_il,
#     num_actv_bc_tl,
     num_tl_120dpd_2m,
#     num_tl_30dpd,
#     num_tl_90g_dpd_24m,
#     num_tl_op_past_12m,
#     open_act_il,
#     pub_rec_bankruptcies,
     term,
#     title,
#     total_cu_tl,
     loan_amnt,
#     all_util,
     avg_cur_bal,
#     collections_12_mths_ex_med,
     dti,
     installment,
#     max_bal_bc,
#     num_accts_ever_120_pd,
#     num_actv_rev_tl,
#     num_bc_sats,
#     num_bc_tl,
#     num_il_tl,
#     num_op_rev_tl,
#     num_rev_accts,
#     num_rev_tl_bal_gt_0,
#     num_sats,
#     open_acc_6m,
#     open_il_12m,
#     open_il_24m,
#     open_rv_12m,
#     open_rv_24m,
#     pct_tl_nvr_dlq,
#     tax_liens,
#     tot_coll_amt,
#     tot_cur_bal,
#     tot_hi_cred_lim,
#     total_bal_il,
#     total_il_high_credit_limit,
#     disbursement_method,
     purpose,
]

all_features = layers.concatenate(
    [
     application_type_encoded,
#     chargeoff_within_12_mths_encoded,
#     emp_title_encoded,
#     inq_fi_encoded,
#     inq_last_12m_encoded,
#     mo_sin_old_rev_tl_op_encoded,
#     mo_sin_rcnt_rev_tl_op_encoded,
#     mo_sin_rcnt_tl_encoded,
#     mths_since_rcnt_il_encoded,
#     num_actv_bc_tl_encoded,
     num_tl_120dpd_2m_encoded,
#     num_tl_30dpd_encoded,
#     num_tl_90g_dpd_24m_encoded,
#     num_tl_op_past_12m_encoded,
#     open_act_il_encoded,
#     pub_rec_bankruptcies_encoded,
     term_encoded,
#     title_encoded,
#     total_cu_tl_encoded,
     loan_amnt_encoded,
#     all_util_encoded,
     avg_cur_bal_encoded,
#     collections_12_mths_ex_med_encoded,
     dti_encoded,
     installment_encoded,
#     max_bal_bc_encoded,
#     num_accts_ever_120_pd_encoded,
#     num_actv_rev_tl_encoded,
#     num_bc_sats_encoded,
#     num_bc_tl_encoded,
#     num_il_tl_encoded,
#     num_op_rev_tl_encoded,
#     num_rev_accts_encoded,
#     num_rev_tl_bal_gt_0_encoded,
#     num_sats_encoded,
#     open_acc_6m_encoded,
#     open_il_12m_encoded,
#     open_il_24m_encoded,
#     open_rv_12m_encoded,
#     open_rv_24m_encoded,
#     pct_tl_nvr_dlq_encoded,
#     tax_liens_encoded,
#     tot_coll_amt_encoded,
#     tot_cur_bal_encoded,
#     tot_hi_cred_lim_encoded,
#     total_bal_il_encoded,
#     total_il_high_credit_limit_encoded,
#     disbursement_method_encoded,
     purpose_encoded,
    ]
)

x = layers.Dense(32, activation="relu")(all_features)
x = layers.Dropout(0.3)(x)
x = layers.Dense(15, activation="relu")(x)
output = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(all_inputs, output)

# %%
model.compile("adam", "binary_crossentropy", metrics=["accuracy"])

# %%
# `rankdir='LR'` is to make the graph horizontal.
keras.utils.plot_model(model,to_file="model4.png", show_shapes=True, rankdir="LR")

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# application_type (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# term (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# purpose (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# string_lookup (StringLookup)    (None, 1)            0           application_type[0][0]
# __________________________________________________________________________________________________
# num_tl_120dpd_2m (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# string_lookup_4 (StringLookup)  (None, 1)            0           term[0][0]
# __________________________________________________________________________________________________
# loan_amnt (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# avg_cur_bal (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# dti (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# installment (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# string_lookup_3 (StringLookup)  (None, 1)            0           purpose[0][0]
# __________________________________________________________________________________________________
# category_encoding_4 (CategoryEn (None, 4)            1           string_lookup[0][0]
# __________________________________________________________________________________________________
# category_encoding_1 (CategoryEn (None, 8)            1           num_tl_120dpd_2m[0][0]
# __________________________________________________________________________________________________
# category_encoding_8 (CategoryEn (None, 4)            1           string_lookup_4[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 1)            3           loan_amnt[0][0]
# __________________________________________________________________________________________________
# normalization_2 (Normalization) (None, 1)            3           avg_cur_bal[0][0]
# __________________________________________________________________________________________________
# normalization_4 (Normalization) (None, 1)            3           dti[0][0]
# __________________________________________________________________________________________________
# normalization_7 (Normalization) (None, 1)            3           installment[0][0]
# __________________________________________________________________________________________________
# category_encoding_7 (CategoryEn (None, 15)           1           string_lookup_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 35)           0           category_encoding_4[0][0]
#                                                                  category_encoding_1[0][0]
#                                                                  category_encoding_8[0][0]
#                                                                  normalization[0][0]
#                                                                  normalization_2[0][0]
#                                                                  normalization_4[0][0]
#                                                                  normalization_7[0][0]
#                                                                  category_encoding_7[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 32)           1152        concatenate[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32)           0           dense[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 15)           495         dropout[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            16          dense_1[0][0]
# ==================================================================================================
# Total params: 1,679
# Trainable params: 1,663
# Non-trainable params: 16
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath='ia4.model.best.tf', verbose=1, save_best_only=True)

logdir = "logs/scalars/ia4-" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

model.fit(train_ds, epochs=50,
          callbacks=[tensorboard_callback,checkpointer],
          validation_data=val_ds)
# Out:
# Epoch 1/50
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\engine\functional.py:540: UserWarning: Input dict contained keys ['emp_title', 'title', 'collections_12_mths_ex_med', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'chargeoff_within_12_mths', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq', 'pub_rec_bankruptcies', 'tax_liens', 'tot_hi_cred_lim', 'total_il_high_credit_limit', 'disbursement_method'] which did not match any model input. They will be ignored by the model.
#   warnings.warn(
#     1/14657 [..............................] - ETA: 14s - loss: 0.6748 - accuracy: 0.4688WARNING:tensorflow:From c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\ops\summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
#     2/14657 [..............................] - ETA: 44:50 - loss: 0.6882 - accuracy: 0.4219WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0150s vs `on_train_batch_end` time: 0.3392s). Check your callbacks.
# 14657/14657 [==============================] - ETA: 0s - loss: 0.2936 - accuracy: 0.8740
# Epoch 00001: val_loss improved from inf to 0.18754, saving model to ia4.model.best.tf
# WARNING:tensorflow:From c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Model.state_updates (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# WARNING:tensorflow:From c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\training\tracking\tracking.py:111: Layer.updates (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# This property should not be used in TensorFlow 2.0, as updates are applied automatically.
# INFO:tensorflow:Assets written to: ia4.model.best.tf\assets
# 14657/14657 [==============================] - 200s 14ms/step - loss: 0.2936 - accuracy: 0.8740 - val_loss: 0.1875 - val_accuracy: 0.9338
# Epoch 2/50
# 14656/14657 [============================>.] - ETA: 0s - loss: 0.2133 - accuracy: 0.9185
# Epoch 00002: val_loss improved from 0.18754 to 0.18115, saving model to ia4.model.best.tf
# INFO:tensorflow:Assets written to: ia4.model.best.tf\assets
# 14657/14657 [==============================] - 208s 14ms/step - loss: 0.2133 - accuracy: 0.9185 - val_loss: 0.1812 - val_accuracy: 0.9382
# Epoch 3/50
# 14656/14657 [============================>.] - ETA: 0s - loss: 0.2070 - accuracy: 0.9217 ETA: 0s - loss: 0.2070 - accura
# Epoch 00003: val_loss did not improve from 0.18115
# 14657/14657 [==============================] - 208s 14ms/step - loss: 0.2070 - accuracy: 0.9217 - val_loss: 0.1843 - val_accuracy: 0.9361
# Epoch 4/50
# 14656/14657 [============================>.] - ETA: 0s - loss: 0.2038 - accuracy: 0.9235
# Epoch 00004: val_loss did not improve from 0.18115
# 14657/14657 [==============================] - 210s 14ms/step - loss: 0.2037 - accuracy: 0.9235 - val_loss: 0.1869 - val_accuracy: 0.9313
# Epoch 5/50
# 14656/14657 [============================>.] - ETA: 0s - loss: 0.2008 - accuracy: 0.9249
# Epoch 00005: val_loss improved from 0.18115 to 0.16792, saving model to ia4.model.best.tf
# INFO:tensorflow:Assets written to: ia4.model.best.tf\assets
# 14657/14657 [==============================] - 209s 14ms/step - loss: 0.2008 - accuracy: 0.9249 - val_loss: 0.1679 - val_accuracy: 0.9437
# Epoch 6/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.2009 - accuracy: 0.9250
# Epoch 00006: val_loss did not improve from 0.16792
# 14657/14657 [==============================] - 208s 14ms/step - loss: 0.2009 - accuracy: 0.9250 - val_loss: 0.1841 - val_accuracy: 0.9327
# Epoch 7/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1985 - accuracy: 0.9265
# Epoch 00007: val_loss did not improve from 0.16792
# 14657/14657 [==============================] - 214s 15ms/step - loss: 0.1985 - accuracy: 0.9265 - val_loss: 0.1926 - val_accuracy: 0.9257
# Epoch 8/50
# 14656/14657 [============================>.] - ETA: 0s - loss: 0.1973 - accuracy: 0.9267
# Epoch 00008: val_loss improved from 0.16792 to 0.16481, saving model to ia4.model.best.tf
50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1756 - accuracy: 0.9382
# Epoch 00044: val_loss did not improve from 0.15804
# 14657/14657 [==============================] - 650s 44ms/step - loss: 0.1756 - accuracy: 0.9382 - val_loss: 0.1609 - val_accuracy: 0.9467
# Epoch 45/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1757 - accuracy: 0.9383
# Epoch 00045: val_loss did not improve from 0.15804
# 14657/14657 [==============================] - 652s 44ms/step - loss: 0.1757 - accuracy: 0.9383 - val_loss: 0.1745 - val_accuracy: 0.9370
# Epoch 46/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1752 - accuracy: 0.9389
# Epoch 00046: val_loss did not improve from 0.15804
# 14657/14657 [==============================] - 635s 43ms/step - loss: 0.1752 - accuracy: 0.9389 - val_loss: 0.1608 - val_accuracy: 0.9486
# Epoch 47/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1745 - accuracy: 0.9389
# Epoch 00047: val_loss did not improve from 0.15804
# 14657/14657 [==============================] - 658s 45ms/step - loss: 0.1745 - accuracy: 0.9389 - val_loss: 0.1621 - val_accuracy: 0.9494
# Epoch 48/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1750 - accuracy: 0.9387
# Epoch 00048: val_loss did not improve from 0.15804
# 14657/14657 [==============================] - 664s 45ms/step - loss: 0.1750 - accuracy: 0.9387 - val_loss: 0.1661 - val_accuracy: 0.9438
# Epoch 49/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1750 - accuracy: 0.9389
# Epoch 00049: val_loss did not improve from 0.15804
# 14657/14657 [==============================] - 653s 45ms/step - loss: 0.1750 - accuracy: 0.9389 - val_loss: 0.1646 - val_accuracy: 0.9453
# Epoch 50/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1749 - accuracy: 0.9392
# Epoch 00050: val_loss did not improve from 0.15804
# 14657/14657 [==============================] - 662s 45ms/step - loss: 0.1749 - accuracy: 0.9392 - val_loss: 0.1631 - val_accuracy: 0.9472

# %%
model.save('my_model4.tf')
# Out:
# INFO:tensorflow:Assets written to: my_model4.tf\assets

# %%
all_inputs = [
     application_type,
#     chargeoff_within_12_mths,
#     emp_title,
#     inq_fi,
#     inq_last_12m,
#     mo_sin_old_rev_tl_op,
#     mo_sin_rcnt_rev_tl_op,
#     mo_sin_rcnt_tl,
#     mths_since_rcnt_il,
#     num_actv_bc_tl,
     num_tl_120dpd_2m,
     num_tl_30dpd,
     num_tl_90g_dpd_24m,
     num_tl_op_past_12m,
#     open_act_il,
     pub_rec_bankruptcies,
     term,
#     title,
#     total_cu_tl,
     loan_amnt,
#     all_util,
     avg_cur_bal,
#     collections_12_mths_ex_med,
     dti,
     installment,
#     max_bal_bc,
#     num_accts_ever_120_pd,
#     num_actv_rev_tl,
#     num_bc_sats,
#     num_bc_tl,
#     num_il_tl,
#     num_op_rev_tl,
#     num_rev_accts,
#     num_rev_tl_bal_gt_0,
#     num_sats,
#     open_acc_6m,
#     open_il_12m,
#     open_il_24m,
#     open_rv_12m,
#     open_rv_24m,
#     pct_tl_nvr_dlq,
#     tax_liens,
#     tot_coll_amt,
#     tot_cur_bal,
#     tot_hi_cred_lim,
#     total_bal_il,
#     total_il_high_credit_limit,
#     disbursement_method,
     purpose,
]

all_features = layers.concatenate(
    [
     application_type_encoded,
#     chargeoff_within_12_mths_encoded,
#     emp_title_encoded,
#     inq_fi_encoded,
#     inq_last_12m_encoded,
#     mo_sin_old_rev_tl_op_encoded,
#     mo_sin_rcnt_rev_tl_op_encoded,
#     mo_sin_rcnt_tl_encoded,
#     mths_since_rcnt_il_encoded,
#     num_actv_bc_tl_encoded,
     num_tl_120dpd_2m_encoded,
     num_tl_30dpd_encoded,
     num_tl_90g_dpd_24m_encoded,
     num_tl_op_past_12m_encoded,
#     open_act_il_encoded,
     pub_rec_bankruptcies_encoded,
     term_encoded,
#     title_encoded,
#     total_cu_tl_encoded,
     loan_amnt_encoded,
#     all_util_encoded,
     avg_cur_bal_encoded,
#     collections_12_mths_ex_med_encoded,
     dti_encoded,
     installment_encoded,
#     max_bal_bc_encoded,
#     num_accts_ever_120_pd_encoded,
#     num_actv_rev_tl_encoded,
#     num_bc_sats_encoded,
#     num_bc_tl_encoded,
#     num_il_tl_encoded,
#     num_op_rev_tl_encoded,
#     num_rev_accts_encoded,
#     num_rev_tl_bal_gt_0_encoded,
#     num_sats_encoded,
#     open_acc_6m_encoded,
#     open_il_12m_encoded,
#     open_il_24m_encoded,
#     open_rv_12m_encoded,
#     open_rv_24m_encoded,
#     pct_tl_nvr_dlq_encoded,
#     tax_liens_encoded,
#     tot_coll_amt_encoded,
#     tot_cur_bal_encoded,
#     tot_hi_cred_lim_encoded,
#     total_bal_il_encoded,
#     total_il_high_credit_limit_encoded,
#     disbursement_method_encoded,
     purpose_encoded,
    ]
)

x = layers.Dense(25, activation="relu")(all_features)
x = layers.Dropout(0.1)(x)
x = layers.Dense(30, activation="relu")(x)
x = layers.Dense(10, activation="relu")(x)
output = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(all_inputs, output)

# %%
model.compile("adam", "binary_crossentropy", metrics=["accuracy"])

# %%
# `rankdir='LR'` is to make the graph horizontal.
keras.utils.plot_model(model,to_file="model5.png", show_shapes=True, rankdir="LR")

# %%
model.summary()
# Out:
# Model: "functional_14"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# application_type (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# term (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# purpose (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# string_lookup_6 (StringLookup)  (None, 1)            0           application_type[0][0]
# __________________________________________________________________________________________________
# num_tl_120dpd_2m (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# num_tl_30dpd (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# num_tl_90g_dpd_24m (InputLayer) [(None, 1)]          0
# __________________________________________________________________________________________________
# num_tl_op_past_12m (InputLayer) [(None, 1)]          0
# __________________________________________________________________________________________________
# pub_rec_bankruptcies (InputLaye [(None, 1)]          0
# __________________________________________________________________________________________________
# string_lookup_10 (StringLookup) (None, 1)            0           term[0][0]
# __________________________________________________________________________________________________
# loan_amnt (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# avg_cur_bal (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# dti (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# installment (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# string_lookup_9 (StringLookup)  (None, 1)            0           purpose[0][0]
# __________________________________________________________________________________________________
# category_encoding_14 (CategoryE (None, 20)           0           string_lookup_6[0][0]
# __________________________________________________________________________________________________
# category_encoding_11 (CategoryE (None, 20)           0           num_tl_120dpd_2m[0][0]
# __________________________________________________________________________________________________
# category_encoding_12 (CategoryE (None, 20)           0           num_tl_30dpd[0][0]
# __________________________________________________________________________________________________
# normalization_62 (Normalization (None, 1)            3           num_tl_90g_dpd_24m[0][0]
# __________________________________________________________________________________________________
# normalization_63 (Normalization (None, 1)            3           num_tl_op_past_12m[0][0]
# __________________________________________________________________________________________________
# category_encoding_13 (CategoryE (None, 20)           0           pub_rec_bankruptcies[0][0]
# __________________________________________________________________________________________________
# category_encoding_18 (CategoryE (None, 20)           0           string_lookup_10[0][0]
# __________________________________________________________________________________________________
# normalization_39 (Normalization (None, 1)            3           loan_amnt[0][0]
# __________________________________________________________________________________________________
# normalization_41 (Normalization (None, 1)            3           avg_cur_bal[0][0]
# __________________________________________________________________________________________________
# normalization_43 (Normalization (None, 1)            3           dti[0][0]
# __________________________________________________________________________________________________
# normalization_46 (Normalization (None, 1)            3           installment[0][0]
# __________________________________________________________________________________________________
# category_encoding_17 (CategoryE (None, 20)           0           string_lookup_9[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 126)          0           category_encoding_14[0][0]
#                                                                  category_encoding_11[0][0]
#                                                                  category_encoding_12[0][0]
#                                                                  normalization_62[0][0]
#                                                                  normalization_63[0][0]
#                                                                  category_encoding_13[0][0]
#                                                                  category_encoding_18[0][0]
#                                                                  normalization_39[0][0]
#                                                                  normalization_41[0][0]
#                                                                  normalization_43[0][0]
#                                                                  normalization_46[0][0]
#                                                                  category_encoding_17[0][0]
# __________________________________________________________________________________________________
# dense_24 (Dense)                (None, 25)           3175        concatenate_7[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 25)           0           dense_24[0][0]
# __________________________________________________________________________________________________
# dense_25 (Dense)                (None, 30)           780         dropout_6[0][0]
# __________________________________________________________________________________________________
# dense_26 (Dense)                (None, 10)           310         dense_25[0][0]
# __________________________________________________________________________________________________
# dense_27 (Dense)                (None, 1)            11          dense_26[0][0]
# ==================================================================================================
# Total params: 4,294
# Trainable params: 4,276
# Non-trainable params: 18
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath='ia5.model.best.tf', verbose=1, save_best_only=True)

logdir = "logs/scalars/ia5-" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

model.fit(train_ds, epochs=50,
          callbacks=[tensorboard_callback,checkpointer],
          validation_data=val_ds)
# Out:
# Epoch 1/50
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\engine\functional.py:540: UserWarning: Input dict contained keys ['emp_title', 'title', 'collections_12_mths_ex_med', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'chargeoff_within_12_mths', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'pct_tl_nvr_dlq', 'tax_liens', 'tot_hi_cred_lim', 'total_il_high_credit_limit', 'disbursement_method'] which did not match any model input. They will be ignored by the model.
#   warnings.warn(
#     2/14657 [..............................] - ETA: 3:32:30 - loss: 0.6878 - accuracy: 0.5781WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0080s vs `on_train_batch_begin` time: 0.0122s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0080s vs `on_train_batch_end` time: 1.7189s). Check your callbacks.
# 14657/14657 [==============================] - ETA: 0s - loss: 0.2786 - accuracy: 0.8804
# Epoch 00001: val_loss improved from inf to 0.19610, saving model to ia5.model.best.tf
# INFO:tensorflow:Assets written to: ia5.model.best.tf\assets
# 14657/14657 [==============================] - 286s 20ms/step - loss: 0.2786 - accuracy: 0.8804 - val_loss: 0.1961 - val_accuracy: 0.9237
# Epoch 2/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.2098 - accuracy: 0.9196
# Epoch 00002: val_loss did not improve from 0.19610
# 14657/14657 [==============================] - 283s 19ms/step - loss: 0.2098 - accuracy: 0.9196 - val_loss: 0.2041 - val_accuracy: 0.9206
# Epoch 3/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0
50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1668 - accuracy: 0.9421
# Epoch 00050: val_loss did not improve from 0.15756
# 14657/14657 [==============================] - 315s 21ms/step - loss: 0.1668 - accuracy: 0.9421 - val_loss: 0.1627 - val_accuracy: 0.9434

# %%
model = tf.keras.models.load_model("ia5.model.best.tf")
model.evaluate(val_ds)
# Out:
# WARNING:tensorflow:5 out of the last 5 calls to <function recreate_function.<locals>.restored_function_body at 0x0000021B4EFD29D0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function recreate_function.<locals>.restored_function_body at 0x0000021B4EFDE940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 21986/21986 [==============================] - 154s 7ms/step - loss: 0.1576 - accuracy: 0.9483
# [0.15756158530712128, 0.948321521282196]

# %%
all_inputs = [
     application_type,
     chargeoff_within_12_mths,
#     emp_title,
#     inq_fi,
#     inq_last_12m,
#     mo_sin_old_rev_tl_op,
#     mo_sin_rcnt_rev_tl_op,
#     mo_sin_rcnt_tl,
#     mths_since_rcnt_il,
#     num_actv_bc_tl,
     num_tl_120dpd_2m,
     num_tl_30dpd,
     num_tl_90g_dpd_24m,
     num_tl_op_past_12m,
#     open_act_il,
     pub_rec_bankruptcies,
     term,
#     title,
#     total_cu_tl,
     loan_amnt,
#     all_util,
     avg_cur_bal,
#     collections_12_mths_ex_med,
     dti,
     installment,
#     max_bal_bc,
#     num_accts_ever_120_pd,
#     num_actv_rev_tl,
#     num_bc_sats,
#     num_bc_tl,
     num_il_tl,
#     num_op_rev_tl,
#     num_rev_accts,
#     num_rev_tl_bal_gt_0,
     num_sats,
#     open_acc_6m,
#     open_il_12m,
#     open_il_24m,
#     open_rv_12m,
#     open_rv_24m,
#     pct_tl_nvr_dlq,
#     tax_liens,
#     tot_coll_amt,
#     tot_cur_bal,
#     tot_hi_cred_lim,
#     total_bal_il,
#     total_il_high_credit_limit,
#     disbursement_method,
     purpose,
]

all_features = layers.concatenate(
    [
     application_type_encoded,
     chargeoff_within_12_mths_encoded,
#     emp_title_encoded,
#     inq_fi_encoded,
#     inq_last_12m_encoded,
#     mo_sin_old_rev_tl_op_encoded,
#     mo_sin_rcnt_rev_tl_op_encoded,
#     mo_sin_rcnt_tl_encoded,
#     mths_since_rcnt_il_encoded,
#     num_actv_bc_tl_encoded,
     num_tl_120dpd_2m_encoded,
     num_tl_30dpd_encoded,
     num_tl_90g_dpd_24m_encoded,
     num_tl_op_past_12m_encoded,
#     open_act_il_encoded,
     pub_rec_bankruptcies_encoded,
     term_encoded,
#     title_encoded,
#     total_cu_tl_encoded,
     loan_amnt_encoded,
#     all_util_encoded,
     avg_cur_bal_encoded,
#     collections_12_mths_ex_med_encoded,
     dti_encoded,
     installment_encoded,
#     max_bal_bc_encoded,
#     num_accts_ever_120_pd_encoded,
#     num_actv_rev_tl_encoded,
#     num_bc_sats_encoded,
#     num_bc_tl_encoded,
     num_il_tl_encoded,
#     num_op_rev_tl_encoded,
#     num_rev_accts_encoded,
#     num_rev_tl_bal_gt_0_encoded,
     num_sats_encoded,
#     open_acc_6m_encoded,
#     open_il_12m_encoded,
#     open_il_24m_encoded,
#     open_rv_12m_encoded,
#     open_rv_24m_encoded,
#     pct_tl_nvr_dlq_encoded,
#     tax_liens_encoded,
#     tot_coll_amt_encoded,
#     tot_cur_bal_encoded,
#     tot_hi_cred_lim_encoded,
#     total_bal_il_encoded,
#     total_il_high_credit_limit_encoded,
#     disbursement_method_encoded,
     purpose_encoded,
    ]
)

x = layers.Dense(15, activation="relu")(all_features)
x = layers.Dense(30, activation="relu")(x)
output = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(all_inputs, output)

# %%
model.compile("adam", "binary_crossentropy", metrics=["accuracy"])

# %%
# `rankdir='LR'` is to make the graph horizontal.
keras.utils.plot_model(model,to_file="model6.png", show_shapes=True, rankdir="LR")

# %%
model.summary()
# Out:
# Model: "functional_10"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# application_type (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# term (InputLayer)               [(None, 1)]          0
# __________________________________________________________________________________________________
# purpose (InputLayer)            [(None, 1)]          0
# __________________________________________________________________________________________________
# string_lookup (StringLookup)    (None, 1)            0           application_type[0][0]
# __________________________________________________________________________________________________
# chargeoff_within_12_mths (Input [(None, 1)]          0
# __________________________________________________________________________________________________
# num_tl_120dpd_2m (InputLayer)   [(None, 1)]          0
# __________________________________________________________________________________________________
# num_tl_30dpd (InputLayer)       [(None, 1)]          0
# __________________________________________________________________________________________________
# num_tl_90g_dpd_24m (InputLayer) [(None, 1)]          0
# __________________________________________________________________________________________________
# num_tl_op_past_12m (InputLayer) [(None, 1)]          0
# __________________________________________________________________________________________________
# pub_rec_bankruptcies (InputLaye [(None, 1)]          0
# __________________________________________________________________________________________________
# string_lookup_4 (StringLookup)  (None, 1)            0           term[0][0]
# __________________________________________________________________________________________________
# loan_amnt (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# avg_cur_bal (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# dti (InputLayer)                [(None, 1)]          0
# __________________________________________________________________________________________________
# installment (InputLayer)        [(None, 1)]          0
# __________________________________________________________________________________________________
# num_il_tl (InputLayer)          [(None, 1)]          0
# __________________________________________________________________________________________________
# num_sats (InputLayer)           [(None, 1)]          0
# __________________________________________________________________________________________________
# string_lookup_3 (StringLookup)  (None, 1)            0           purpose[0][0]
# __________________________________________________________________________________________________
# category_encoding_4 (CategoryEn (None, 4)            1           string_lookup[0][0]
# __________________________________________________________________________________________________
# category_encoding (CategoryEnco (None, 10)           1           chargeoff_within_12_mths[0][0]
# __________________________________________________________________________________________________
# category_encoding_1 (CategoryEn (None, 8)            1           num_tl_120dpd_2m[0][0]
# __________________________________________________________________________________________________
# category_encoding_2 (CategoryEn (None, 5)            1           num_tl_30dpd[0][0]
# __________________________________________________________________________________________________
# normalization_23 (Normalization (None, 1)            3           num_tl_90g_dpd_24m[0][0]
# __________________________________________________________________________________________________
# normalization_24 (Normalization (None, 1)            3           num_tl_op_past_12m[0][0]
# __________________________________________________________________________________________________
# category_encoding_3 (CategoryEn (None, 10)           1           pub_rec_bankruptcies[0][0]
# __________________________________________________________________________________________________
# category_encoding_8 (CategoryEn (None, 4)            1           string_lookup_4[0][0]
# __________________________________________________________________________________________________
# normalization (Normalization)   (None, 1)            3           loan_amnt[0][0]
# __________________________________________________________________________________________________
# normalization_2 (Normalization) (None, 1)            3           avg_cur_bal[0][0]
# __________________________________________________________________________________________________
# normalization_4 (Normalization) (None, 1)            3           dti[0][0]
# __________________________________________________________________________________________________
# normalization_7 (Normalization) (None, 1)            3           installment[0][0]
# __________________________________________________________________________________________________
# normalization_18 (Normalization (None, 1)            3           num_il_tl[0][0]
# __________________________________________________________________________________________________
# normalization_22 (Normalization (None, 1)            3           num_sats[0][0]
# __________________________________________________________________________________________________
# category_encoding_7 (CategoryEn (None, 15)           1           string_lookup_3[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 64)           0           category_encoding_4[0][0]
#                                                                  category_encoding[0][0]
#                                                                  category_encoding_1[0][0]
#                                                                  category_encoding_2[0][0]
#                                                                  normalization_23[0][0]
#                                                                  normalization_24[0][0]
#                                                                  category_encoding_3[0][0]
#                                                                  category_encoding_8[0][0]
#                                                                  normalization[0][0]
#                                                                  normalization_2[0][0]
#                                                                  normalization_4[0][0]
#                                                                  normalization_7[0][0]
#                                                                  normalization_18[0][0]
#                                                                  normalization_22[0][0]
#                                                                  category_encoding_7[0][0]
# __________________________________________________________________________________________________
# dense_18 (Dense)                (None, 15)           975         concatenate_5[0][0]
# __________________________________________________________________________________________________
# dense_19 (Dense)                (None, 30)           480         dense_18[0][0]
# __________________________________________________________________________________________________
# dense_20 (Dense)                (None, 1)            31          dense_19[0][0]
# ==================================================================================================
# Total params: 1,517
# Trainable params: 1,486
# Non-trainable params: 31
# __________________________________________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
checkpointer = ModelCheckpoint(filepath='ia6.model.best.tf', verbose=1, save_best_only=True)

logdir = "logs/scalars/ia6-" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = keras.callbacks.TensorBoard(log_dir=logdir)

model.fit(train_ds, epochs=50,
          callbacks=[tensorboard_callback,checkpointer],
          validation_data=val_ds)
# Out:
# Epoch 1/50
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\engine\functional.py:540: UserWarning: Input dict contained keys ['emp_title', 'title', 'collections_12_mths_ex_med', 'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_act_il', 'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util', 'inq_fi', 'total_cu_tl', 'inq_last_12m', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'pct_tl_nvr_dlq', 'tax_liens', 'tot_hi_cred_lim', 'total_il_high_credit_limit', 'disbursement_method'] which did not match any model input. They will be ignored by the model.
#   warnings.warn(
#     2/14657 [..............................] - ETA: 2:03:16 - loss: 0.7211 - accuracy: 0.3750WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0070s vs `on_train_batch_begin` time: 0.0130s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0070s vs `on_train_batch_end` time: 0.9885s). Check your callbacks.
# 14657/14657 [==============================] - ETA: 0s - loss: 0.3016 - accuracy: 0.8776
# Epoch 00001: val_loss improved from inf to 0.22578, saving model to ia6.model.best.tf
# INFO:tensorflow:Assets written to: ia6.model.best.tf\assets
# 14657/14657 [==============================] - 284s 19ms/step - loss: 0.3016 - accuracy: 0.8776 - val_loss: 0.2258 - val_accuracy: 0.9227
# Epoch 2/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.2110 - accuracy: 0.9238
# Epoch 00002: val_loss improved from 0.22578 to 0.19624, saving model to ia6.model.best.tf
# INFO:tensorflow:Assets written to: ia6.model.best.tf\assets
# 14657/14657 [==============================] - 283s 19ms/step - loss: 0.2110 - accuracy: 0.9238 - val_loss: 0.1962 - val_accuracy: 0.9281
# Epoch 3/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1924 - accuracy: 0.9289
# Epoch 00003: val_loss improved from 0.19624 to 0.18326, saving model to ia6.model.best.tf
# INFO:tensorflow:Assets written to: ia6.model.best.tf\assets
# 14657/14657 [==============================] - 287s 20ms/step - loss: 0.1924 - accuracy: 0.9289 - val_loss: 0.1833 - val_accuracy: 0.9336
# Epoch 4/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1875 - accuracy: 0.9307
# Epoch 00004: val_loss improved from 0.18326 to 0.17662, saving model to ia6.model.best.tf
# INFO:tensorflow:Assets written to: ia6.model.best.tf\assets
# 14657/14657 [==============================] - 285s 19ms/step - loss: 0.1875 - accuracy: 0.9307 - val_loss: 0.1766 - val_accuracy: 0.9380
# Epoch 5/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.
50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9390
# Epoch 00017: val_loss did not improve from 0.16812
# 14657/14657 [==============================] - 284s 19ms/step - loss: 0.1720 - accuracy: 0.9390 - val_loss: 0.1684 - val_accuracy: 0.9406
# Epoch 18/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1720 - accuracy: 0.9389
# Epoch 00018: val_loss did not improve from 0.16812
# 14657/14657 [==============================] - 285s 19ms/step - loss: 0.1720 - accuracy: 0.9389 - val_loss: 0.1819 - val_accuracy: 0.9310
# Epoch 19/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1716 - accuracy: 0.9393
# Epoch 00019: val_loss improved from 0.16812 to 0.16746, saving model to ia6.model.best.tf
# INFO:tensorflow:Assets written to: ia6.model.best.tf\assets
# 14657/14657 [==============================] - 287s 20ms/step - loss: 0.1716 - accuracy: 0.9393 - val_loss: 0.1675 - val_accuracy: 0.9423
# Epoch 20/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1717 - accuracy: 0.9393
# Epoch 00020: val_loss improved from 0.16746 to 0.16628, saving model to ia6.model.best.tf
# INFO:tensorflow:Assets written to: ia6.model.best.tf\assets
# 14657/14657 [==============================] - 286s 20ms/step - loss: 0.1717 - accuracy: 0.9393 - val_loss: 0.1663 - val_accuracy: 0.9420
# Epoch 21/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1705 - accuracy: 0.9399
# Epoch 00021: val_loss improved from 0.16628 to 0.16326, saving model to ia6.model.best.tf
# INFO:tensorflow:Assets written to: ia6.model.best.tf\assets
# 14657/14657 [==============================] - 287s 20ms/step - loss: 0.1705 - accuracy: 0.9399 - val_loss: 0.1633 - val_accuracy: 0.9448
# Epoch 22/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1708 - accuracy: 0.9397
# Epoch 00022: val_loss did not improve from 0.16326
# 14657/14657 [==============================] - 284s 19ms/step - loss: 0.1708 - accuracy: 0.9397 - val_loss: 0.1713 - val_accuracy: 0.9382
# Epoch 23/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1702 - accuracy: 0.9401
# Epoch 00023: val_loss did not improve from 0.16326
# 14657/14657 [==============================] - 284s 19ms/step - loss: 0.1702 - accuracy: 0.9401 - val_loss: 0.1664 - val_accuracy: 0.9415
# Epoch 24/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1698 - accuracy: 0.9403
# Epoch 00024: val_loss did not improve from 0.16326
# 14657/14657 [==============================] - 284s 19ms/step - loss: 0.1698 - accuracy: 0.9403 - val_loss: 0.1837 - val_accuracy: 0.9291
# Epoch 25/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1700 - accuracy: 0.9402
# Epoch 00025: val_loss did not improve from 0.16326
# 14657/14657 [==============================] - 285s 19ms/step - loss: 0.1700 - accuracy: 0.9402 - val_loss: 0.1690 - val_accuracy: 0.9403
# Epoch 26/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1689 - accuracy: 0.9409
# Epoch 00026: val_loss improved from 0.16326 to 0.16086, saving model to ia6.model.best.tf
# INFO:tensorflow:Assets written to: ia6.model.best.tf\assets
# 14657/14657 [==============================] - 288s 20ms/step - loss: 0.1689 - accuracy: 0.9409 - val_loss: 0.1609 - val_accuracy: 0.9457
# Epoch 27/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1682 - accuracy: 0.9410
# Epoch 00027: val_loss did not improve from 0.16086
# 14657/14657 [==============================] - 286s 20ms/step - loss: 0.1682 - accuracy: 0.9410 - val_loss: 0.1617 - val_accuracy: 0.9442
# Epoch 28/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1684 - accuracy: 0.9409
# Epoch 00028: val_loss did not improve from 0.16086
# 14657/14657 [==============================] - 285s 19ms/step - loss: 0.1684 - accuracy: 0.9409 - val_loss: 0.1795 - val_accuracy: 0.9325
# Epoch 29/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1678 - accuracy: 0.9414
# Epoch 00029: val_loss did not improve from 0.16086
# 14657/14657 [==============================] - 286s 19ms/step - loss: 0.1678 - accuracy: 0.9414 - val_loss: 0.1642 - val_accuracy: 0.9433
# Epoch 30/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1678 - accuracy: 0.9415
# Epoch 00030: val_loss did not improve from 0.16086
# 14657/14657 [==============================] - 288s 20ms/step - loss: 0.1678 - accuracy: 0.9415 - val_loss: 0.1914 - val_accuracy: 0.9284
# Epoch 31/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1674 - accuracy: 0.9415
# Epoch 00031: val_loss did not improve from 0.16086
# 14657/14657 [==============================] - 287s 20ms/step - loss: 0.1674 - accuracy: 0.9415 - val_loss: 0.1643 - val_accuracy: 0.9444
# Epoch 32/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1675 - accuracy: 0.9415
# Epoch 00032: val_loss did not improve from 0.16086
# 14657/14657 [==============================] - 286s 19ms/step - loss: 0.1675 - accuracy: 0.9415 - val_loss: 0.2192 - val_accuracy: 0.9165
# Epoch 33/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1675 - accuracy: 0.9415
# Epoch 00033: val_loss improved from 0.16086 to 0.15774, saving model to ia6.model.best.tf
# INFO:tensorflow:Assets written to: ia6.model.best.tf\assets
# 14657/14657 [==============================] - 290s 20ms/step - loss: 0.1675 - accuracy: 0.9415 - val_loss: 0.1577 - val_accuracy: 0.9486
# Epoch 34/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1673 - accuracy: 0.9415
# Epoch 00034: val_loss did not improve from 0.15774
# 14657/14657 [==============================] - 285s 19ms/step - loss: 0.1673 - accuracy: 0.9415 - val_loss: 0.1635 - val_accuracy: 0.9433
# Epoch 35/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1666 - accuracy: 0.9419
# Epoch 00035: val_loss did not improve from 0.15774
# 14657/14657 [==============================] - 286s 20ms/step - loss: 0.1666 - accuracy: 0.9419 - val_loss: 0.1774 - val_accuracy: 0.9353
# Epoch 36/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1663 - accuracy: 0.9421
# Epoch 00036: val_loss did not improve from 0.15774
# 14657/14657 [==============================] - 284s 19ms/step - loss: 0.1663 - accuracy: 0.9421 - val_loss: 0.1633 - val_accuracy: 0.9442
# Epoch 37/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9425
# Epoch 00037: val_loss did not improve from 0.15774
# 14657/14657 [==============================] - 286s 20ms/step - loss: 0.1658 - accuracy: 0.9425 - val_loss: 0.1810 - val_accuracy: 0.9317
# Epoch 38/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1659 - accuracy: 0.9424
# Epoch 00038: val_loss did not improve from 0.15774
# 14657/14657 [==============================] - 287s 20ms/step - loss: 0.1659 - accuracy: 0.9424 - val_loss: 0.1889 - val_accuracy: 0.9299
# Epoch 39/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1657 - accuracy: 0.9425
# Epoch 00039: val_loss did not improve from 0.15774
# 14657/14657 [==============================] - 293s 20ms/step - loss: 0.1657 - accuracy: 0.9425 - val_loss: 0.1600 - val_accuracy: 0.9477
# Epoch 40/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1656 - accuracy: 0.9424
# Epoch 00040: val_loss did not improve from 0.15774
# 14657/14657 [==============================] - 301s 21ms/step - loss: 0.1656 - accuracy: 0.9424 - val_loss: 0.1680 - val_accuracy: 0.9402
# Epoch 41/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1655 - accuracy: 0.9425
# Epoch 00041: val_loss did not improve from 0.15774
# 14657/14657 [==============================] - 304s 21ms/step - loss: 0.1655 - accuracy: 0.9425 - val_loss: 0.1612 - val_accuracy: 0.9466
# Epoch 42/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1652 - accuracy: 0.9429
# Epoch 00042: val_loss did not improve from 0.15774
# 14657/14657 [==============================] - 312s 21ms/step - loss: 0.1652 - accuracy: 0.9429 - val_loss: 0.1609 - val_accuracy: 0.9462
# Epoch 43/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1650 - accuracy: 0.9430
# Epoch 00043: val_loss improved from 0.15774 to 0.15757, saving model to ia6.model.best.tf
# INFO:tensorflow:Assets written to: ia6.model.best.tf\assets
# 14657/14657 [==============================] - 309s 21ms/step - loss: 0.1650 - accuracy: 0.9430 - val_loss: 0.1576 - val_accuracy: 0.9481
# Epoch 44/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1653 - accuracy: 0.9428
# Epoch 00044: val_loss did not improve from 0.15757
# 14657/14657 [==============================] - 308s 21ms/step - loss: 0.1653 - accuracy: 0.9428 - val_loss: 0.1727 - val_accuracy: 0.9391
# Epoch 45/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1644 - accuracy: 0.9433
# Epoch 00045: val_loss did not improve from 0.15757
# 14657/14657 [==============================] - 301s 21ms/step - loss: 0.1644 - accuracy: 0.9433 - val_loss: 0.1625 - val_accuracy: 0.9445
# Epoch 46/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1647 - accuracy: 0.9430
# Epoch 00046: val_loss did not improve from 0.15757
# 14657/14657 [==============================] - 304s 21ms/step - loss: 0.1647 - accuracy: 0.9430 - val_loss: 0.1655 - val_accuracy: 0.9425
# Epoch 47/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1644 - accuracy: 0.9433
# Epoch 00047: val_loss did not improve from 0.15757
# 14657/14657 [==============================] - 311s 21ms/step - loss: 0.1644 - accuracy: 0.9433 - val_loss: 0.1710 - val_accuracy: 0.9402
# Epoch 48/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1643 - accuracy: 0.9431
# Epoch 00048: val_loss did not improve from 0.15757
# 14657/14657 [==============================] - 334s 23ms/step - loss: 0.1643 - accuracy: 0.9431 - val_loss: 0.1597 - val_accuracy: 0.9475
# Epoch 49/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1645 - accuracy: 0.9431
# Epoch 00049: val_loss did not improve from 0.15757
# 14657/14657 [==============================] - 347s 24ms/step - loss: 0.1645 - accuracy: 0.9431 - val_loss: 0.1719 - val_accuracy: 0.9392
# Epoch 50/50
# 14657/14657 [==============================] - ETA: 0s - loss: 0.1635 - accuracy: 0.9439
# Epoch 00050: val_loss did not improve from 0.15757
# 14657/14657 [==============================] - 306s 21ms/step - loss: 0.1635 - accuracy: 0.9439 - val_loss: 0.1620 - val_accuracy: 0.9446

# %%
model.save('my_model6.tf')
# Out:
# INFO:tensorflow:Assets written to: my_model6.tf\assets

# %%
dataframe.groupby("application_type")["application_type"].count()
# Out:
# application_type
# Individual    1074110
# Joint App       98428
# Name: application_type, dtype: int64

# %%
dataframe.groupby("purpose")["purpose"].count()
# Out:
# purpose
# car                    13044
# credit_card           263755
# debt_consolidation    643226
# educational                1
# home_improvement       84892
# house                   9011
# major_purchase         28928
# medical                16013
# moving                  8732
# other                  82523
# renewable_energy         752
# small_business         12370
# vacation                9286
# wedding                    5
# Name: purpose, dtype: int64

# %%
dataframe.groupby("term")["term"].count()
# Out:
# term
#  36 months    837284
#  60 months    335254
# Name: term, dtype: int64

# %%
dataframe.groupby("pub_rec_bankruptcies")["pub_rec_bankruptcies"].count()
# Out:
# pub_rec_bankruptcies
# 0    1029266
# 1     136626
# 2       5190
# 3       1033
# 4        284
# 5         93
# 6         32
# 7          9
# 8          4
# 9          1
# Name: pub_rec_bankruptcies, dtype: int64

# %%
dataframe[[
"application_type",
"chargeoff_within_12_mths",
"num_tl_120dpd_2m",
"num_tl_30dpd",
"num_tl_90g_dpd_24m",
"num_tl_op_past_12m",
"pub_rec_bankruptcies",
"term",
"loan_amnt",
"avg_cur_bal",
"dti",
"installment",
"num_il_tl",
"num_sats",
"purpose",
"is_risky"
]].query("is_risky == 1")
# Out:
#         application_type  chargeoff_within_12_mths  num_tl_120dpd_2m  \
# 5             Individual                         0                 0
# 6             Individual                         0                 0
# 7             Individual                         0                 0
# 8             Individual                         0                 0
# 12            Individual                         0                 0
# ...                  ...                       ...               ...
# 1172527       Individual                         0                 0
# 1172529       Individual                         0                 0
# 1172530       Individual                         0                 0
# 1172534       Individual                         0                 0
# 1172536       Individual                         0                 0
#
#          num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  \
# 5                   0                 0.0                 2.0
# 6                   0                 1.0                 0.0
# 7                   0                 0.0                 2.0
# 8                   0                 0.0                 2.0
# 12                  0                 0.0                 0.0
# ...               ...                 ...                 ...
# 1172527             0                 0.0                 2.0
# 1172529             0                 0.0                 1.0
# 1172530             0                 0.0                 0.0
# 1172534             0                 0.0                 5.0
# 1172536             0                 0.0                 0.0
#
#          pub_rec_bankruptcies        term  loan_amnt  avg_cur_bal        dti  \
# 5                           0   36 months    20000.0      30030.0  14.670000
# 6                           0   36 months    20000.0      17700.0  17.610001
# 7                           1   36 months    10000.0       1997.0  13.070000
# 8                           0   36 months     8000.0      28528.0  34.799999
# 12                          0   36 months    28000.0      13819.0  21.600000
# ...                       ...         ...        ...          ...        ...
# 1172527                     0   36 months    15000.0       9090.0  26.400000
# 1172529                     0   60 months    28000.0      13740.0  22.230000
# 1172530                     0   60 months    40000.0      39101.0  15.470000
# 1172534                     0   60 months    24000.0       2088.0  10.980000
# 1172536                     0   60 months    24000.0       6369.0  34.939999
#
#          installment  num_il_tl  num_sats             purpose  is_risky
# 5         637.580017        7.0      12.0  debt_consolidation         1
# 6         631.260010        9.0       8.0      major_purchase         1
# 7         306.450012        3.0      14.0         credit_card         1
# 8         263.739990        5.0       8.0         credit_card         1
# 12        858.049988        4.0      16.0  debt_consolidation         1
# ...              ...        ...       ...                 ...       ...
# 1172527   487.470001        3.0      24.0  debt_consolidation         1
# 1172529   581.099976       32.0      22.0  debt_consolidation         1
# 1172530   859.559998        6.0       7.0  debt_consolidation         1
# 1172534   515.739990        1.0      15.0         credit_card         1
# 1172536   515.739990       17.0      24.0  debt_consolidation         1
#
# [566544 rows x 16 columns]

# %%
model = tf.keras.models.load_model("my_model6.tf")

sample = {
    "application_type": ["Individual"],
    "chargeoff_within_12_mths": [1],
    "num_tl_120dpd_2m": [1],
    "num_tl_30dpd": [3],
    "num_tl_90g_dpd_24m": [233],
    "num_tl_op_past_12m": [1],
    "pub_rec_bankruptcies": [1],
    "term": ["36 months"],
    "loan_amnt": [1000],
    "avg_cur_bal": [1000],
    "dti": [0.4],
    "installment": [300],
    "num_il_tl": [2],
    "num_sats": [3],
    "purpose": ["car"],
}
sample_df = pd.DataFrame (sample, sample.keys(),
#                           dtype = {
# 'loan_amnt': np.float32,
# 'term' : str, 
# 'installment' : np.float32,
# 'purpose' : 'str', 
# 'dti' : np.float32,
# 'application_type' : 'str', 
# 'total_bal_il' : np.float32,
# 'avg_cur_bal' : np.float32,
# 'chargeoff_within_12_mths' : np.float32,
# 'num_il_tl' : np.float32,
# 'num_sats' : np.float32,
# 'num_tl_120dpd_2m' : np.float32,
# 'num_tl_30dpd' : np.float32,
# 'num_tl_90g_dpd_24m' : np.float32,
# 'num_tl_op_past_12m' : np.float32,
# 'pub_rec_bankruptcies' : np.float32,
#     }
                         )

#Individual	0	0	0	0.0	2.0	0	36 months	20000.0	30030.0	14.670000	637.580017	7.0	12.0	debt_consolidation
sample2 = {
    "application_type": "Individual",
    "chargeoff_within_12_mths": 0,
    "num_tl_120dpd_2m": 0,
    "num_tl_30dpd": 0,
    "num_tl_90g_dpd_24m": 0,
    "num_tl_op_past_12m": 2,
    "pub_rec_bankruptcies": 0,
    "term": "36 months",
    "loan_amnt": 20000,
    "avg_cur_bal": 30030,
    "dti": 14.67,
    "installment": 637.58,
    "num_il_tl":7.0,
    "num_sats": 12,
    "purpose": "debt_consolidation",
}
#ds = tf.data.Dataset.from_tensor_slices((dict(sample_df), sample_df))
input_dict = {name: tf.convert_to_tensor([value]) for name, value in sample.items()}
predictions = model.predict(input_dict)
print(predictions)

# TIENE QUE REENTRENAR :C
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-70-dbddd3d3b400> in <module>
# ----> 1 model = tf.keras.models.load_model("my_model6.tf")
#       2
#       3 sample = {
#       4     "application_type": ["Individual"],
#       5     "chargeoff_within_12_mths": [1],
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\saving\save.py in load_model(filepath, custom_objects, compile, options)
#     185     if isinstance(filepath, six.string_types):
#     186       loader_impl.parse_saved_model(filepath)
# --> 187       return saved_model_load.load(filepath, compile, options)
#     188
#     189   raise IOError(
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in load(path, compile, options)
#     118   # TODO(kathywu): Add code to load from objects that contain all endpoints
#     119
# --> 120   model = tf_load.load_internal(
#     121       path, options=options, loader_cls=KerasObjectLoader)
#     122
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\saved_model\load.py in load_internal(export_dir, tags, options, loader_cls)
#     630     with ops.init_scope():
#     631       try:
# --> 632         loader = loader_cls(object_graph_proto, saved_model_proto, export_dir,
#     633                             ckpt_options)
#     634       except errors.NotFoundError as err:
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in __init__(self, *args, **kwargs)
#     192     self._models_to_reconstruct = []
#     193
# --> 194     super(KerasObjectLoader, self).__init__(*args, **kwargs)
#     195
#     196     # Now that the node object has been fully loaded, and the checkpoint has
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\saved_model\load.py in __init__(self, object_graph_proto, saved_model_proto, export_dir, ckpt_options)
#     128       self._concrete_functions[name] = _WrapperFunction(concrete_function)
#     129
# --> 130     self._load_all()
#     131     self._restore_checkpoint()
#     132
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in _load_all(self)
#     219
#     220     # Finish setting up layers and models. See function docstring for more info.
# --> 221     self._finalize_objects()
#     222
#     223   @property
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in _finalize_objects(self)
#     528
#     529     # Initialize graph networks, now that layer dependencies have been resolved.
# --> 530     self._reconstruct_all_models()
#     531
#     532   def _unblock_model_reconstruction(self, layer_id, layer):
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in _reconstruct_all_models(self)
#     546       all_initialized_models.add(model_id)
#     547       model, layers = self.model_layer_dependencies[model_id]
# --> 548       self._reconstruct_model(model_id, model, layers)
#     549       self._add_object_graph_edges(self._proto.nodes[model_id], model_id)
#     550       _finalize_config_layers([model])
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\saving\saved_model\load.py in _reconstruct_model(self, model_id, model, layers)
#     586     else:
#     587       (inputs, outputs,
# --> 588        created_layers) = functional_lib.reconstruct_from_config(
#     589            config, created_layers={layer.name: layer for layer in layers})
#     590       model.__init__(inputs, outputs, name=config['name'])
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\engine\functional.py in reconstruct_from_config(config, custom_objects, created_layers)
#    1212       if layer in unprocessed_nodes:
#    1213         for node_data in unprocessed_nodes.pop(layer):
# -> 1214           process_node(layer, node_data)
#    1215
#    1216   input_tensors = []
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\engine\functional.py in process_node(layer, node_data)
#    1160     if input_tensors is not None:
#    1161       input_tensors = base_layer_utils.unnest_if_single_tensor(input_tensors)
# -> 1162       output_tensors = layer(input_tensors, **kwargs)
#    1163
#    1164       # Update node index map.
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in __call__(self, *args, **kwargs)
#     923     # >> model = tf.keras.Model(inputs, outputs)
#     924     if _in_functional_construction_mode(self, inputs, args, kwargs, input_list):
# --> 925       return self._functional_construction_call(inputs, args, kwargs,
#     926                                                 input_list)
#     927
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\engine\base_layer.py in _functional_construction_call(self, inputs, args, kwargs, input_list)
#    1115           try:
#    1116             with ops.enable_auto_cast_variables(self._compute_dtype_object):
# -> 1117               outputs = call_fn(cast_inputs, *args, **kwargs)
#    1118
#    1119           except errors.OperatorNotAllowedInGraphError as e:
#
# c:\users\paula\onedrive - escuela superior politécnica del litoral\guillermo\ia\ia\lib\site-packages\tensorflow\python\keras\layers\preprocessing\category_encoding.py in call(self, inputs, count_weights)
#     280       out_depth = K.get_value(self.num_elements)
#     281       if out_depth == 0:
# --> 282         raise RuntimeError(
#     283             "If you construct a `CategoryEncoding` layer with "
#     284             "`max_tokens=None`, you need to call `adapt()` "
#
# RuntimeError: If you construct a `CategoryEncoding` layer with `max_tokens=None`, you need to call `adapt()` on it before using it
